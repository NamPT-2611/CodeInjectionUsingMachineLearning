# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Data CAPEC mutilable dataset

# %%
df_capec = pd.read_csv('Dataset/data_capec_multilabel.csv')
# Out:
# /tmp/ipykernel_51021/1247042814.py:1: DtypeWarning: Columns (9,11,12,13,14,15,16,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_capec = pd.read_csv('Dataset/data_capec_multilabel.csv')

# %%
df_capec.head()
# Out:
#                     timestamp      src_ip  src_port      dst_ip  dst_port  \
# 0  17/Jul/2020:12:23:34 +0100  172.26.0.1   55894.0  172.26.0.4      80.0
# 1  17/Jul/2020:12:23:41 +0100  172.26.0.1   55897.0  172.26.0.4      80.0
# 2  17/Jul/2020:12:23:51 +0100  172.26.0.1   55901.0  172.26.0.4      80.0
# 3  17/Jul/2020:12:23:51 +0100  172.26.0.1   55902.0  172.26.0.4      80.0
# 4  17/Jul/2020:12:23:58 +0100  172.26.0.1   55903.0  172.26.0.4      80.0
#
#   request_http_method                               request_http_request  \
# 0                 GET                                                  /
# 1                 GET  /blog/index.php/2020/04/04/voluptatum-reprehen...
# 2                 GET                               /blog/xmlrpc.php?rsd
# 3                 GET                                                  /
# 4                 GET  /blog/index.php/2020/04/04/nihil-tenetur-et-ad...
#
#   request_http_protocol                                 request_user_agent  \
# ...

# %%
## Delete blank text in http request
df_capec = df_capec[df_capec['request_http_request'] != '/']

# %% [markdown]
# ## Convert from multlabel to multiclass

# %%
df_capec.shape
# Out:
# (608806, 38)

# %%
def count_duplicates(a0, a1, a2, a3, a4, a5, a6, a7, a8, a9, a10, a11, a12, a13):
    return a0+a1+a2+a3+a4+a5+a6+a7+a8+a9+a10+a11+a12+a13
df_capec['count'] = df_capec.apply(lambda x: count_duplicates(x['000 - Normal'],x['272 - Protocol Manipulation'], x['242 - Code Injection'],x['88 - OS Command Injection'],x['126 - Path Traversal'],x['66 - SQL Injection'],x['16 - Dictionary-based Password Attack'],x['310 - Scanning for Vulnerable Software'],x['153 - Input Data Manipulation'],x['248 - Command Injection'],x['274 - HTTP Verb Tampering'],x['194 - Fake the Source of Data'],x['34 - HTTP Response Splitting'],x['33 - HTTP Request Smuggling']), axis = 1)

# %% [markdown]
# ### Data with only multiclass

# %%
df_multiclass = df_capec[df_capec['count'] == 1]

df_multiclass.shape
# Out:
# (599755, 39)

# %%
df_multiclass.head()
# Out:
#                     timestamp      src_ip  src_port      dst_ip  dst_port  \
# 1  17/Jul/2020:12:23:41 +0100  172.26.0.1   55897.0  172.26.0.4      80.0
# 2  17/Jul/2020:12:23:51 +0100  172.26.0.1   55901.0  172.26.0.4      80.0
# 4  17/Jul/2020:12:23:58 +0100  172.26.0.1   55903.0  172.26.0.4      80.0
# 5  17/Jul/2020:12:24:07 +0100  172.26.0.1   55910.0  172.26.0.4      80.0
# 6  17/Jul/2020:12:24:15 +0100  172.26.0.1   55911.0  172.26.0.4      80.0
#
#   request_http_method                               request_http_request  \
# 1                 GET  /blog/index.php/2020/04/04/voluptatum-reprehen...
# 2                 GET                               /blog/xmlrpc.php?rsd
# 4                 GET  /blog/index.php/2020/04/04/nihil-tenetur-et-ad...
# 5                 GET  /blog/index.php/2020/04/04/explicabo-qui-fuga-...
# 6                 GET  /blog/index.php/2020/04/04/explicabo-qui-fuga-...
#
#   request_http_protocol                                 request_user_agent  \
# ...

# %% [markdown]
# ### Data with multilabel

# %%
df_multilabel = df_capec[df_capec['count'] > 1]
df_multilabel.shape
# Out:
# (9051, 39)

# %%
df_multilabel.head()
# Out:
#                        timestamp      src_ip  src_port      dst_ip  dst_port  \
# 2940  17/Jul/2020:19:01:39 +0200  172.26.0.1   45500.0  172.26.0.4      80.0
# 2961  17/Jul/2020:19:11:23 +0200  172.26.0.1   47482.0  172.26.0.4      80.0
# 2969  17/Jul/2020:19:25:15 +0200  172.26.0.1   59862.0  172.26.0.4      80.0
# 2974  17/Jul/2020:19:25:16 +0200  172.26.0.1   59862.0  172.26.0.4      80.0
# 2977  17/Jul/2020:19:25:16 +0200  172.26.0.1   59862.0  172.26.0.4      80.0
#
#      request_http_method                               request_http_request  \
# 2940                POST  /vendor/phpunit/phpunit/src/Util/PHP/eval-stdi...
# 2961                POST                               /cgi-bin/ViewLog.asp
# 2969                 GET                                        /.svn/wc.db
# 2974                 GET                                   /blog/.svn/wc.db
# 2977                 GET              /blog/index.php/my-account/.svn/wc.db
#
# ...

# %%
#Assign for test only
df_capec = df_multiclass

# %% [markdown]
# ## 000 - Normal

# %%
df_000 = df_capec[df_capec['000 - Normal'] == 1].loc[:, ['request_http_method', 
                                                         'request_http_request',
                                                         'request_body',
                                                         '000 - Normal']].reset_index(drop=True)
df_000.shape
# Out:
# (226509, 4)

# %%
df_000 = df_capec[df_capec['000 - Normal'] == 1]
df_000.shape
# Out:
# (226509, 39)

# %%
df_000.head()
# Out:
#                     timestamp      src_ip  src_port      dst_ip  dst_port  \
# 1  17/Jul/2020:12:23:41 +0100  172.26.0.1   55897.0  172.26.0.4      80.0
# 2  17/Jul/2020:12:23:51 +0100  172.26.0.1   55901.0  172.26.0.4      80.0
# 4  17/Jul/2020:12:23:58 +0100  172.26.0.1   55903.0  172.26.0.4      80.0
# 5  17/Jul/2020:12:24:07 +0100  172.26.0.1   55910.0  172.26.0.4      80.0
# 6  17/Jul/2020:12:24:15 +0100  172.26.0.1   55911.0  172.26.0.4      80.0
#
#   request_http_method                               request_http_request  \
# 1                 GET  /blog/index.php/2020/04/04/voluptatum-reprehen...
# 2                 GET                               /blog/xmlrpc.php?rsd
# 4                 GET  /blog/index.php/2020/04/04/nihil-tenetur-et-ad...
# 5                 GET  /blog/index.php/2020/04/04/explicabo-qui-fuga-...
# 6                 GET  /blog/index.php/2020/04/04/explicabo-qui-fuga-...
#
#   request_http_protocol                                 request_user_agent  \
# ...

# %% [markdown]
# ## 272 - Protocol Manipulation

# %%
df_272 = df_capec[df_capec['272 - Protocol Manipulation'] == 1].loc[:, ['request_http_method',
                                                                        'request_http_request', 
                                                                        'request_body', 
                                                                        '272 - Protocol Manipulation']].reset_index(drop=True)
df_272.shape
# Out:
# (6924, 4)

# %%
df_272 = df_capec[df_capec['272 - Protocol Manipulation']==1]
df_272.shape
# Out:
# (6924, 39)

# %%
df_272.head()
# Out:
#                        timestamp      src_ip  src_port      dst_ip  dst_port  \
# 3461  17/Jul/2020:19:30:37 +0200  172.26.0.1   59927.0  172.26.0.4      80.0
# 7138  17/Jul/2020:19:58:39 +0200  172.26.0.1   63015.0  172.26.0.4      80.0
# 7139  17/Jul/2020:19:58:39 +0200  172.26.0.1   63016.0  172.26.0.4      80.0
# 7508  17/Jul/2020:20:09:38 +0200  172.26.0.1   64214.0  172.26.0.4      80.0
# 7509  17/Jul/2020:20:09:38 +0200  172.26.0.1   64213.0  172.26.0.4      80.0
#
#      request_http_method                               request_http_request  \
# 3461                 GET                        /blog/index.php/my-account/
# 7138                 GET  /blog/wp-content/uploads/2020/04/c874f043-4188...
# 7139                 GET  /blog/wp-content/uploads/2020/04/5d0beb80-cdb9...
# 7508                 GET  /blog/wp-content/uploads/2020/04/8427d570-74b5...
# 7509                 GET  /blog/wp-content/uploads/2020/04/cda5c6a3-e3d9...
#
# ...

# %% [markdown]
# ## 242 - Code Injection

# %%
df_242 = df_capec[df_capec['242 - Code Injection'] == 1].loc[:, ['request_http_method',
                                                                        'request_http_request', 
                                                                        'request_body', 
                                                                        '242 - Code Injection']].reset_index(drop=True)
df_242.shape
# Out:
# (13792, 4)

# %%
df_242 = df_capec[df_capec['242 - Code Injection'] == 1]
df_242.shape
# Out:
# (13792, 39)

# %%
df_242.head()
# Out:
#                          timestamp      src_ip  src_port      dst_ip  \
# 7491    17/Jul/2020:20:08:51 +0200  172.26.0.1   36158.0  172.26.0.4
# 110025  17/Jul/2020:23:36:11 +0200  172.26.0.1   50100.0  172.26.0.4
# 110026  17/Jul/2020:23:36:12 +0200  172.26.0.1   50101.0  172.26.0.4
# 110067  17/Jul/2020:23:36:19 +0200  172.26.0.1   50103.0  172.26.0.4
# 110068  17/Jul/2020:23:36:19 +0200  172.26.0.1   50101.0  172.26.0.4
#
#         dst_port request_http_method  \
# 7491        80.0                 GET
# 110025      80.0                POST
# 110026      80.0                POST
# 110067      80.0                 GET
# 110068      80.0                POST
#
#                                      request_http_request  \
# 7491    /index.php?s=/Index/\x5Cthink\x5Capp/invokefun...
# 110025          /blog/index.php/my-account/edit-password/
# 110026          /blog/index.php/my-account/edit-password/
# 110067  /blog/index.php/my-account/edit-profile/post.p...
# ...

# %% [markdown]
# ## 88 - OS Command Injection

# %%
df_88 = df_capec[df_capec['88 - OS Command Injection'] == 1].loc[:, ['request_http_method',
                                                                        'request_http_request', 
                                                                        'request_body', 
                                                                        '88 - OS Command Injection']].reset_index(drop=True)
df_88.shape
# Out:
# (3074, 4)

# %%
df_88 = df_capec[df_capec['88 - OS Command Injection'] == 1]
df_88.shape
# Out:
# (3074, 39)

# %%
df_88.head()
# Out:
#                          timestamp      src_ip  src_port      dst_ip  \
# 7494    17/Jul/2020:20:08:52 +0200  172.26.0.1   36158.0  172.26.0.4
# 257238  18/Jul/2020:04:08:39 +0200  172.26.0.1   63219.0  172.26.0.4
# 257240  18/Jul/2020:04:08:39 +0200  172.26.0.1   63219.0  172.26.0.4
# 257242  18/Jul/2020:04:08:40 +0200  172.26.0.1   63219.0  172.26.0.4
# 257244  18/Jul/2020:04:08:40 +0200  172.26.0.1   63219.0  172.26.0.4
#
#         dst_port request_http_method  \
# 7494        80.0                 GET
# 257238      80.0                POST
# 257240      80.0                POST
# 257242      80.0                POST
# 257244      80.0                POST
#
#                                      request_http_request  \
# 7494    /index.php?s=/module/action/param1/${@die(sha1...
# 257238          /blog/index.php/my-account/edit-password/
# 257240          /blog/index.php/my-account/edit-password/
# 257242          /blog/index.php/my-account/edit-password/
# ...

# %% [markdown]
# ## 126 - Path Traversal

# %%
df_126 = df_capec[df_capec['126 - Path Traversal'] == 1].loc[:, ['request_http_method','request_http_request', 'request_body', '000 - Normal']].reset_index(drop=True)
df_126.shape
# Out:
# (17595, 4)

# %%
df_126 = df_capec[df_capec['126 - Path Traversal'] == 1]
df_126.shape
# Out:
# (17595, 39)

# %%
df_126.head()
# Out:
#                        timestamp      src_ip  src_port      dst_ip  dst_port  \
# 2968  17/Jul/2020:19:25:15 +0200  172.26.0.1   59862.0  172.26.0.4      80.0
# 2970  17/Jul/2020:19:25:15 +0200  172.26.0.1   59862.0  172.26.0.4      80.0
# 2973  17/Jul/2020:19:25:16 +0200  172.26.0.1   59862.0  172.26.0.4      80.0
# 2975  17/Jul/2020:19:25:16 +0200  172.26.0.1   59862.0  172.26.0.4      80.0
# 2976  17/Jul/2020:19:25:16 +0200  172.26.0.1   59862.0  172.26.0.4      80.0
#
#      request_http_method                     request_http_request  \
# 2968                 GET                            /.svn/entries
# 2970                 GET                              /.git/index
# 2973                 GET                       /blog/.svn/entries
# 2975                 GET                         /blog/.git/index
# 2976                 GET  /blog/index.php/my-account/.svn/entries
#
#      request_http_protocol                                 request_user_agent  \
# ...

# %% [markdown]
# ## 66 - SQL Injection

# %%
df_66 = df_capec[df_capec['66 - SQL Injection'] == 1].loc[:, ['request_http_method',
                                                              'request_http_request', 
                                                              'request_body', 
                                                              '66 - SQL Injection']].reset_index(drop=True)
df_66.shape
# Out:
# (248093, 4)

# %%
df_66 = df_capec[df_capec['66 - SQL Injection'] == 1]
df_66.shape
# Out:
# (248093, 39)

# %%
df_66.head()
# Out:
#                        timestamp      src_ip  src_port      dst_ip  dst_port  \
# 3121  17/Jul/2020:19:25:48 +0200  172.26.0.1   59867.0  172.26.0.4      80.0
# 4255  17/Jul/2020:19:33:20 +0200  172.26.0.1   59968.0  172.26.0.4      80.0
# 7159  17/Jul/2020:20:01:20 +0200  172.26.0.1   63063.0  172.26.0.4      80.0
# 7758  17/Jul/2020:21:27:43 +0200  172.26.0.1   64594.0  172.26.0.4      80.0
# 8188  17/Jul/2020:21:29:12 +0200  172.26.0.1   64609.0  172.26.0.4      80.0
#
#      request_http_method                               request_http_request  \
# 3121                 GET  /blog/wp-admin/load-styles.php?c=0&dir=ltr&loa...
# 4255                 GET  /blog/wp-admin/load-styles.php?c=0&dir=ltr&loa...
# 7159                 GET  /blog/wp-admin/load-styles.php?c=0&dir=ltr&loa...
# 7758                 GET  /blog/wp-admin/load-styles.php?c=0&dir=ltr&loa...
# 8188                 GET  /blog/wp-admin/load-styles.php?c=0&dir=ltr&loa...
#
# ...

# %% [markdown]
# ## 16 - Dictionary-based Password Attack

# %%
df_16 = df_capec[df_capec['16 - Dictionary-based Password Attack'] == 1]
df_16.shape
# Out:
# (836, 39)

# %%
df_16.head()
# Out:
#                        timestamp      src_ip  src_port      dst_ip  dst_port  \
# 3122  17/Jul/2020:19:25:48 +0200  172.26.0.1   59863.0  172.26.0.4      80.0
# 3351  17/Jul/2020:19:26:25 +0200  172.26.0.1   59870.0  172.26.0.4      80.0
# 4565  17/Jul/2020:19:33:33 +0200  172.26.0.1   59973.0  172.26.0.4      80.0
# 4730  17/Jul/2020:19:33:50 +0200  172.26.0.1   59975.0  172.26.0.4      80.0
# 4731  17/Jul/2020:19:33:50 +0200  172.26.0.1   59975.0  172.26.0.4      80.0
#
#      request_http_method request_http_request request_http_protocol  \
# 3122                POST   /blog/wp-login.php              HTTP/1.1
# 3351                POST   /blog/wp-login.php              HTTP/1.1
# 4565                POST   /blog/wp-login.php              HTTP/1.1
# 4730                POST   /blog/wp-login.php              HTTP/1.1
# 4731                POST   /blog/wp-login.php              HTTP/1.1
#
#                                      request_user_agent  \
# ...

# %% [markdown]
# ## 310 - Scanning for Vulnerable Software

# %%
df_310 = df_capec[df_capec['310 - Scanning for Vulnerable Software'] == 1]
df_310.shape
# Out:
# (2382, 39)

# %%
df_310.head()
# Out:
#                        timestamp      src_ip  src_port      dst_ip  dst_port  \
# 4738  17/Jul/2020:19:35:52 +0200  172.26.0.1   60004.0  172.26.0.4      80.0
# 4741  17/Jul/2020:19:35:52 +0200  172.26.0.1   60012.0  172.26.0.4      80.0
# 4742  17/Jul/2020:19:35:52 +0200  172.26.0.1   60006.0  172.26.0.4      80.0
# 4747  17/Jul/2020:19:35:52 +0200  172.26.0.1   60013.0  172.26.0.4      80.0
# 4748  17/Jul/2020:19:35:53 +0200  172.26.0.1   60008.0  172.26.0.4      80.0
#
#      request_http_method             request_http_request  \
# 4738                 GET        /nmaplowercheck1595007349
# 4741                 GET        /nmaplowercheck1595007350
# 4742                 GET                    /wp-login.php
# 4747                 GET  /index.php/wp-json/wp/v2/posts/
# 4748                 GET                 /crossdomain.xml
#
#      request_http_protocol                                 request_user_agent  \
# ...

# %% [markdown]
# ## 153 - Input Data Manipulation

# %%
df_153 = df_capec[df_capec['153 - Input Data Manipulation'] == 1]
df_153.shape
# Out:
# (1387, 39)

# %%
df_153.head()
# Out:
#                         timestamp      src_ip  src_port      dst_ip  dst_port  \
# 19406  17/Jul/2020:21:48:16 +0200  172.26.0.1   64765.0  172.26.0.4      80.0
# 19411  17/Jul/2020:21:48:17 +0200  172.26.0.1   64763.0  172.26.0.4      80.0
# 19413  17/Jul/2020:21:48:17 +0200  172.26.0.1   64765.0  172.26.0.4      80.0
# 19415  17/Jul/2020:21:48:17 +0200  172.26.0.1   64765.0  172.26.0.4      80.0
# 19416  17/Jul/2020:21:48:17 +0200  172.26.0.1   64763.0  172.26.0.4      80.0
#
#       request_http_method                       request_http_request  \
# 19406                POST  /blog/index.php/my-account/edit-password/
# 19411                POST  /blog/index.php/my-account/edit-password/
# 19413                POST  /blog/index.php/my-account/edit-password/
# 19415                POST  /blog/index.php/my-account/edit-password/
# 19416                POST  /blog/index.php/my-account/edit-password/
#
#       request_http_protocol  \
# 19406              HTTP/1.1
# ...

# %% [markdown]
# ## 274 - HTTP Verb Tampering

# %%
df_274 = df_capec[df_capec['274 - HTTP Verb Tampering'] == 1]
df_274.shape
# Out:
# (4047, 39)

# %%
df_274.head()
# Out:
#                          timestamp      src_ip  src_port      dst_ip  \
# 534146  19/Jul/2020:11:41:49 +0200  172.26.0.1   54485.0  172.26.0.4
# 534156  19/Jul/2020:11:41:49 +0200  172.26.0.1   54488.0  172.26.0.4
# 534163  19/Jul/2020:11:41:50 +0200  172.26.0.1   54486.0  172.26.0.4
# 534170  19/Jul/2020:11:41:51 +0200  172.26.0.1   54492.0  172.26.0.4
# 534177  19/Jul/2020:11:41:51 +0200  172.26.0.1   54493.0  172.26.0.4
#
#         dst_port request_http_method       request_http_request  \
# 534146      80.0               TRACK                     /O8AQS
# 534156      80.0               TRACK                 /blogYDQJC
# 534163      80.0               TRACK       /blog/index.php0NEKM
# 534170      80.0               TRACK       /blog/index.php87RYI
# 534177      80.0               TRACK  /blog/index.php/2020SS8Q8
#
#        request_http_protocol request_user_agent request_referer  \
# 534146              HTTP/1.1                NaN             NaN
# ...

# %% [markdown]
# ## 194 - Fake the Source of Data

# %%
df_194 = df_capec[df_capec['194 - Fake the Source of Data'] == 1]
df_194.shape
# Out:
# (55982, 39)

# %%
df_194.head()
# Out:
#                         timestamp      src_ip  src_port      dst_ip  dst_port  \
# 44501  17/Jul/2020:22:24:07 +0200  172.26.0.1   65225.0  172.26.0.4      80.0
# 44502  17/Jul/2020:22:24:07 +0200  172.26.0.1   65227.0  172.26.0.4      80.0
# 44504  17/Jul/2020:22:24:07 +0200  172.26.0.1   65228.0  172.26.0.4      80.0
# 44505  17/Jul/2020:22:24:07 +0200  172.26.0.1   65227.0  172.26.0.4      80.0
# 44506  17/Jul/2020:22:24:07 +0200  172.26.0.1   65227.0  172.26.0.4      80.0
#
#       request_http_method                            request_http_request  \
# 44501                 GET                 /http%3A%2F%2Fwww.google.com%2F
# 44502                 GET       /http%3A%2F%2Fwww.google.com%2F/index.php
# 44504                 GET            /http%3A%2F%2Fwww.google.com%3A80%2F
# 44505                 GET  /http%3A%2F%2Fwww.google.com%3A80%2F/index.php
# 44506                 GET                    /http%3A%2F%2Fwww.google.com
#
#       request_http_protocol  \
# ...

# %% [markdown]
# ## 34 - HTTP Response Splitting

# %%
df_34 = df_capec[df_capec['34 - HTTP Response Splitting'] == 1].loc[:, ['request_http_method',
                                                                        'request_http_request', 
                                                                        'request_body', 
                                                                        '34 - HTTP Response Splitting']].reset_index(drop=True)
df_34.shape
# Out:
# (19134, 4)

# %%
df_34 = df_capec[df_capec['34 - HTTP Response Splitting'] == 1]
df_34.shape
# Out:
# (19134, 39)

# %%
df_34.head()
# Out:
#                          timestamp      src_ip  src_port      dst_ip  \
# 242072  18/Jul/2020:03:22:32 +0200  172.26.0.1   62915.0  172.26.0.4
# 242073  18/Jul/2020:03:22:32 +0200  172.26.0.1   62914.0  172.26.0.4
# 242096  18/Jul/2020:03:22:34 +0200  172.26.0.1   62915.0  172.26.0.4
# 242097  18/Jul/2020:03:22:34 +0200  172.26.0.1   62914.0  172.26.0.4
# 242121  18/Jul/2020:03:22:37 +0200  172.26.0.1   62915.0  172.26.0.4
#
#         dst_port request_http_method  \
# 242072      80.0                 GET
# 242073      80.0                 GET
# 242096      80.0                 GET
# 242097      80.0                 GET
# 242121      80.0                 GET
#
#                             request_http_request request_http_protocol  \
# 242072            /blog%0Acat+%2Fetc%2Fpasswd%0A              HTTP/1.1
# 242073  /blog%0Acat+%2Fetc%2Fpasswd%0A/index.php              HTTP/1.1
# 242096                       /blog%0Asleep+15%0A              HTTP/1.1
# ...

# %% [markdown]
# ## Note on data
# - Có 2 trường attack ko có tấn công trong bộ dataset multiclass:
#     + 33 - HTTP Request Smuggling
#     + 248 - Command Injection
# Lý do có thể vì hai trường attack này giao với các trường attack khác (multilabel)
# - Tổng cộng các loại tấn công (đã bỏ 2 loại attack bên trên): 12 (bao gồm normal):
#     1. 000 - Normal: 226509
#     2. 272 - Protocol Manipulation: 6924
#     3. 242 - Code Injection: 13792
#     4. 88 - OS Command Injection: 3074
#     5. 126 - Path Traversal: 17595
#     6. 66 - SQL Injection: 248093
#     7. 16 - Dictionary-based Password Attack: 836
#     8. 310 - Scanning for Vulnerable Software: 2382
#     9. 153 - Input Data Manipulation: 1387
#     10. 274 - HTTP Verb Tampering: 4047
#     11. 194 - Fake the Source of Data: 55982
#     12. 34 - HTTP Response Splitting: 19134
# - Mỗi sample có rất nhiều trường dữ liệu, tuy nhiên chỉ có 1 số attribute giúp classify web attacking
# - Thử nghiệm với concat 2 trường dữ liệu: request_http_request và request_body (với method POST)
# - Thử nghiệm với một vài kiểu tấn công, và để lại một vài kiểu tấn công có cùng variance với bộ dataset để nghiên cứu Transfer Learning
# - Các kiểu tấn công sử dụng trong dataset:
#     + 272 - Protocol Manipulation
#     + 242 - Code Injection
#     + 126 - Path Traversal
#     + 66 - SQL Injection
#     + 310 - Scanning for Vulnerable Software
#     + 153 - Input Data Manipulation
#     + 194 - Fake the Source of Data
#     + 34 - HTTP Response Splitting
# - Kiểu tấn công dành cho Transfer Learning: 88-OS Command Injection
# - Hiện tại đang chưa tích hợp bộ dataset CSIC 2010-2012 (Bao gồm XSS attack và SQLi attack)

# %% [markdown]
# ## Prepare and format data

# %%
# Concat http_method with http_request and http_content

# %%
def create_text(method, request, body):
    if method == 'GET':
        return str(method) + ' ' + str(request)
    return str(method) + ' ' + str(request) + ' ' + str(body)

df_capec['text'] = df_capec.apply(lambda x: create_text(x['request_http_method'], 
                                                        x['request_http_request'], 
                                                        x['request_body']), axis = 1)
df_capec.head()
# Out:
#                     timestamp      src_ip  src_port      dst_ip  dst_port  \
# 1  17/Jul/2020:12:23:41 +0100  172.26.0.1   55897.0  172.26.0.4      80.0
# 2  17/Jul/2020:12:23:51 +0100  172.26.0.1   55901.0  172.26.0.4      80.0
# 4  17/Jul/2020:12:23:58 +0100  172.26.0.1   55903.0  172.26.0.4      80.0
# 5  17/Jul/2020:12:24:07 +0100  172.26.0.1   55910.0  172.26.0.4      80.0
# 6  17/Jul/2020:12:24:15 +0100  172.26.0.1   55911.0  172.26.0.4      80.0
#
#   request_http_method                               request_http_request  \
# 1                 GET  /blog/index.php/2020/04/04/voluptatum-reprehen...
# 2                 GET                               /blog/xmlrpc.php?rsd
# 4                 GET  /blog/index.php/2020/04/04/nihil-tenetur-et-ad...
# 5                 GET  /blog/index.php/2020/04/04/explicabo-qui-fuga-...
# 6                 GET  /blog/index.php/2020/04/04/explicabo-qui-fuga-...
#
#   request_http_protocol                                 request_user_agent  \
# ...

# %%
# Mapping values for classification

def count_duplicate(a0,a1,a2,a3,a4,a5,a6,a7,a8,a9,a10,a11,a12,a13):
    if a0 == 1:
        return '000 - Normal'
    elif a1 == 1:
        return '272 - Protocol Manipulation'
    elif a2 == 1:
        return '242 - Code Injection'
    elif a3 == 1:
        return '88 - OS Command Injection'
    elif a4 == 1:
        return '126 - Path Traversal'
    elif a5 == 1:
        return '66 - SQL Injection'
    elif a6 == 1:
        return '16 - Dictionary-based Password Attack'
    elif a7 == 1:
        return '310 - Scanning for Vulnerable Software'
    elif a8 == 1:
        return '153 - Input Data Manipulation'
    elif a9 == 1:
        return '248 - Command Injection'
    elif a10 == 1:
        return '274 - HTTP Verb Tampering'
    elif a11 == 1:
        return '194 - Fake the Source of Data'
    elif a12 == 1:
        return '34 - HTTP Response Splitting'
    elif a13 == 1:
        return '33 - HTTP Request Smuggling'
    return 'Error'

df_capec['label'] = df_capec.apply(lambda x: count_duplicate(x['000 - Normal'],
                                                             x['272 - Protocol Manipulation'], 
                                                             x['242 - Code Injection'],
                                                             x['88 - OS Command Injection'],
                                                             x['126 - Path Traversal'],
                                                             x['66 - SQL Injection'],
                                                             x['16 - Dictionary-based Password Attack'],
                                                             x['310 - Scanning for Vulnerable Software'],
                                                             x['153 - Input Data Manipulation'],
                                                             x['248 - Command Injection'],
                                                             x['274 - HTTP Verb Tampering'],
                                                             x['194 - Fake the Source of Data'],
                                                             x['34 - HTTP Response Splitting'],
                                                             x['33 - HTTP Request Smuggling']), axis = 1)
df_capec.head()
# Out:
#                     timestamp      src_ip  src_port      dst_ip  dst_port  \
# 1  17/Jul/2020:12:23:41 +0100  172.26.0.1   55897.0  172.26.0.4      80.0
# 2  17/Jul/2020:12:23:51 +0100  172.26.0.1   55901.0  172.26.0.4      80.0
# 4  17/Jul/2020:12:23:58 +0100  172.26.0.1   55903.0  172.26.0.4      80.0
# 5  17/Jul/2020:12:24:07 +0100  172.26.0.1   55910.0  172.26.0.4      80.0
# 6  17/Jul/2020:12:24:15 +0100  172.26.0.1   55911.0  172.26.0.4      80.0
#
#   request_http_method                               request_http_request  \
# 1                 GET  /blog/index.php/2020/04/04/voluptatum-reprehen...
# 2                 GET                               /blog/xmlrpc.php?rsd
# 4                 GET  /blog/index.php/2020/04/04/nihil-tenetur-et-ad...
# 5                 GET  /blog/index.php/2020/04/04/explicabo-qui-fuga-...
# 6                 GET  /blog/index.php/2020/04/04/explicabo-qui-fuga-...
#
#   request_http_protocol                                 request_user_agent  \
# ...

# %%
df_training = df_capec[(df_capec['label'] != '33 - HTTP Request Smuggling')
                       & (df_capec['label'] != '248 - Command Injection') 
                       & (df_capec['label'] != '16 - Dictionary-based Password Attack') 
                       & (df_capec['label'] != '274 - HTTP Verb Tampering') 
                       & (df_capec['label'] != '88 - OS Command Injection')]
df_training.shape
# Out:
# (591798, 41)

# %%
df_capec.shape
# Out:
# (599755, 41)

# %%
df_training.label.unique()
# Out:
# array(['000 - Normal', '126 - Path Traversal', '66 - SQL Injection',
#        '272 - Protocol Manipulation',
#        '310 - Scanning for Vulnerable Software', '242 - Code Injection',
#        '153 - Input Data Manipulation', '194 - Fake the Source of Data',
#        '34 - HTTP Response Splitting'], dtype=object)

# %%
df_final = df_training.loc[:, ['text','label']].reset_index(drop=True)
df_final.head()
# Out:
#                                                 text         label
# 0  GET /blog/index.php/2020/04/04/voluptatum-repr...  000 - Normal
# 1                           GET /blog/xmlrpc.php?rsd  000 - Normal
# 2  GET /blog/index.php/2020/04/04/nihil-tenetur-e...  000 - Normal
# 3  GET /blog/index.php/2020/04/04/explicabo-qui-f...  000 - Normal
# 4  GET /blog/index.php/2020/04/04/explicabo-qui-f...  000 - Normal

# %%
# Save to csv
df_final.to_csv('Dataset/dataset_capec_test.csv', encoding='utf-8', index=False)
